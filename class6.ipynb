# %% [markdown]
# <a href="https://colab.research.google.com/github/Sidahmedhammoudi/CHE4230/blob/main/class6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('/1.csv', encoding='latin1')

# %%
df.head(10)
# Out:
#    ola_mES_2i_2_10.counts  ola_mES_2i_2_11.counts  ...  ola_mES_lif_3_96.counts  Unnamed: 703
# 0                     272                     368  ...                      644           278
# 1                       0                       0  ...                        0             0
# 2                     271                     983  ...                      161            39
# 3                       0                       0  ...                       25           214
# 4                       0                       0  ...                        0             0
# 5                       0                       0  ...                        0             0
# 6                      16                       0  ...                        0             0
# 7                       0                       0  ...                        0             1
# 8                     517                    1588  ...                      280            63
# 9                       0                       1  ...                        0           141
#
# [10 rows x 704 columns]

# %%
df.describe()
# Out:
#        ola_mES_2i_2_10.counts  ola_mES_2i_2_11.counts  ...  ola_mES_lif_3_96.counts  Unnamed: 703
# count            38653.000000            38653.000000  ...             38653.000000  38653.000000
# mean                85.117455              160.751248  ...                62.934339     38.596952
# std                586.271462             1132.187939  ...              1317.051799    724.998934
# min                  0.000000                0.000000  ...                 0.000000      0.000000
# 25%                  0.000000                0.000000  ...                 0.000000      0.000000
# 50%                  0.000000                0.000000  ...                 0.000000      0.000000
# 75%                  4.000000                5.000000  ...                 4.000000      2.000000
# max              45350.000000            78237.000000  ...            159166.000000  86913.000000
#
# [8 rows x 704 columns]

# %%
df.shape
# Out:
# (38653, 704)

# %%
df.columns = df.columns.str.upper()

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.mean = df.fillna(df.mean())

# %%
df_drop_dup = df.drop_duplicates()
